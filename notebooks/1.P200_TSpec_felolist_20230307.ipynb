# %%
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.table import Table
from astroquery.xmatch import XMatch
import numpy as np
import pandas as pd
from pathlib import PurePath, PureWindowsPath

# %%
def rela_specpath(s):
    news = s.replace("file:///","")
    if '\\' in news:
        parts = PureWindowsPath(news).parts
    else:
        parts = PurePath(news).parts        
    path = parts[-2]+'/'+parts[-1]
    return path

# %%
df = pd.read_csv('./tspec23a_base.csv')

# %%
df.columns
# Out:
# Index(['spUrl', 'templateGroup', 'templateName', 'z', 'targetID', 'objra',
#        'objdec', 'userClass', 'userComments', 'newpath', 'fname', 'reject'],
#       dtype='object')

# %%
df['relapath'] = df.spUrl.apply(rela_specpath)

# %%
df = df.loc[:, ['objra', 'objdec', 'z', 'userClass', 'relapath']]

# %%
df
# Out:
#         objra     objdec         z   userClass  \
# 0   213.61793  18.946104  0.607259  FeLoStrong
# 1   212.02587  30.913462  0.849031  FeLoStrong
# 2   122.48913  18.301229  0.966473  FeLoStrong
# 3   131.35862   1.058946  1.419353  FeLoStrong
# 4   222.00061  40.719921  0.803417  FeLoStrong
# ..        ...        ...       ...         ...
# 62  137.06907  28.563176  0.786399  FeLoStrong
# 63  163.89057  36.993476  1.577747  FeLoStrong
# 64  233.58433  41.502087  0.927917  FeLoStrong
# 65  162.91499   3.643972  0.867953  FeLoStrong
# 66  140.85641  26.366499  1.588018  FeLoStrong
#
#                                         relapath
# 0               sdss_b/spec-2758-54523-0614.fits
# 1               sdss_a/spec-3862-55276-0124.fits
# 2               sdss_a/spec-1923-53319-0023.fits
# 3               sdss_a/spec-0467-51901-0473.fits
# 4               sdss_a/spec-5172-56071-0836.fits
# ..                                           ...
# 62  spec_cand_snr5new/spec-11344-58438-0640.fits
# 63  spec_cand_snr5new/spec-10269-58220-0671.fits
# 64   spec_cand_snr5new/spec-5165-56063-0847.fits
# 65   spec_cand_snr5new/spec-4774-55659-0258.fits
# 66  spec_cand_snr5new/spec-11677-58510-0991.fits
#
# [67 rows x 5 columns]

# %%
df.rename(columns={'objra':'ra', 'objdec':'dec'}, inplace=True)

# %%
c = SkyCoord(ra=df.ra.values*u.degree, dec=df.dec.values*u.degree,frame='icrs')
srahms = c.ra.to_string(unit=u.hourangle, sep='', precision=2, pad=True)
srahms2 = c.ra.to_string(unit=u.hourangle, sep=':', precision=2, pad=True)
sdecdms = c.dec.to_string(sep='', precision=2, alwayssign=True, pad=True)
sdecdms2 = c.dec.to_string(sep=':', precision=2, alwayssign=True, pad=True)
# df.loc[:,'Name'] = 'J'+pd.Series(srahms)+pd.Series(sdecdms)
s1 = pd.Series(srahms).str.slice(stop=4)
s2 = pd.Series(sdecdms).str.slice(stop=5)
df.loc[:,'Name'] = 'J'+s1+s2
df.loc[:,'Coord'] = pd.Series(srahms2)+' '+pd.Series(sdecdms2)
# df.loc[:,'srahms2'] = srahms2
# df.loc[:,'sdecdms2'] = sdecdms2
# df.query('Jmag<17 and Kmag<16 and 1.2<z<2.4', inplace=True)
# df.sort_values(by='ra', inplace=True)
# df.reset_index(drop=True, inplace=True)

# %%
df.sort_values(by='ra', inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#             ra        dec         z   userClass  \
# 0    23.188772  -0.769442  1.466944  FeLoStrong
# 1    27.964898  -9.537576  1.413104  FeLoStrong
# 2    41.430696   0.097854  1.411013  FeLoStrong
# 3    44.742410  -0.474190  0.875176  FeLoStrong
# 4    45.002320   0.807797  0.891310  FeLoStrong
# ..         ...        ...       ...         ...
# 62  253.159570  41.676525  0.844072  FeLoStrong
# 63  316.803210   0.910959  0.925812  FeLoStrong
# 64  316.990280  -6.336286  0.644846  FeLoStrong
# 65  329.959600  12.788459  1.513768  FeLoStrong
# 66  333.799730  -0.763895  1.478424  FeLoStrong
#
#                             relapath        Name                     Coord
# 0   sdss_a/spec-7847-57012-0409.fits  J0132-0046  01:32:45.31 -00:46:09.99
# 1   sdss_a/spec-0665-52168-0240.fits  J0151-0932  01:51:51.58 -09:32:15.27
# 2   sdss_b/spec-6782-56572-0893.fits  J0245+0005  02:45:43.37 +00:05:52.28
# 3   sdss_a/spec-9372-58074-0974.fits  J0258-0028  02:58:58.18 -00:28:27.08
# 4   sdss_a/spec-0410-51877-0623.fits  J0300+0048  03:00:00.56 +00:48:28.07
# ..                               ...         ...                       ...
# 62  sdss_a/spec-0631-52079-0181.fits  J1652+4140  16:52:38.30 +41:40:35.49
# 63  sdss_a/spec-0985-52431-0522.fits  J2107+0054  21:07:12.77 +00:54:39.45
# 64  sdss_a/spec-0637-52174-0610.fits  J2107-0620  21:07:57.67 -06:20:10.63
# 65  sdss_a/spec-5062-55803-0403.fits  J2159+1247  21:59:50.30 +12:47:18.45
# 66  sdss_a/spec-9146-58042-0018.fits  J2215-0045  22:15:11.94 -00:45:50.02
#
# [67 rows x 7 columns]

# %%
tb = Table.from_pandas(df)

# %%
tbnew = XMatch.query(cat1=tb,
                     cat2='vizier:II/246/out',
                     max_distance=2 * u.arcsec, 
                     colRA1='ra',
                     colDec1='dec')

# %%
tbnew.write('./tspec23a_2mass.fits', overwrite=True)

# %%
df = tbnew.to_pandas()

# %%
df.to_csv('./tspec23a_2mass.csv', index=False)

# %%
df.to_excel('./tspec23a_2mass.xlsx')

# %%
df
# Out:
#      angDist         ra        dec         z   userClass  \
# 0   0.202876   44.74241  -0.474190  0.875176  FeLoStrong
# 1   0.169299   45.00232   0.807797  0.891310  FeLoStrong
# 2   0.205457  120.70079  55.224685  0.663171  FeLoStrong
# 3   0.270512  122.48913  18.301229  0.966473  FeLoStrong
# 4   0.113182  128.84490  42.716203  0.805863  FeLoStrong
# 5   0.179921  140.14830  52.668445  0.794352  FeLoStrong
# 6   0.075513  143.77683  57.925833  1.531131  FeLoStrong
# 7   0.234741  154.86405   2.422622  1.362947  FeLoStrong
# 8   0.554573  155.84501  50.083578  1.592925  FeLoStrong
# 9   0.089065  158.23072   8.584236  0.893494  FeLoStrong
# 10  0.070963  161.24837  36.934765  0.701929  FeLoStrong
# 11  0.022682  163.87001  31.403133  0.493223  FeLoStrong
# 12  0.454011  163.89057  36.993476  1.577747  FeLoStrong
# 13  0.148365  171.35886   0.483701  0.862571  FeLoStrong
# 14  0.297941  172.11797   1.227217  0.893074  FeLoStrong
# 15  0.178136  178.65251   3.001771  1.458185  FeLoStrong
# 16  0.209675  183.67629  28.058105  0.688845  FeLoStrong
# 17  0.605131  194.92834  12.220167  0.751274  FeLoStrong
# 18  0.114360  206.84513  46.907928  0.697429  FeLoStrong
# 19  0.402172  208.36770  46.851708  1.391569  FeLoStrong
# 20  0.169370  212.02587  30.913462  0.849031  FeLoStrong
# 21  0.170845  213.61793  18.946104  0.607259  FeLoStrong
# 22  0.115415  214.75928  12.330388  1.463434  FeLoStrong
# 23  0.054275  222.00061  40.719921  0.803417  FeLoStrong
# 24  0.204830  227.20332  60.931082  1.532846  FeLoStrong
# 25  0.201572  230.96011  39.234787  0.664138  FeLoStrong
# 26  0.201572  230.96011  39.234787  0.661807  FeLoStrong
# 27  0.061570  239.14073  35.299264  1.490875  FeLoStrong
# 28  0.101399  240.43234  15.043818  0.647456  FeLoStrong
# 29  0.930893  241.49526  47.716727  0.899965  FeLoStrong
# 30  0.298416  253.15957  41.676525  0.844072  FeLoStrong
# 31  0.076763  316.99028  -6.336286  0.644846  FeLoStrong
# 32  0.204553  333.79973  -0.763895  1.478424  FeLoStrong
#
#                                         relapath        Name  \
# 0               sdss_a/spec-9372-58074-0974.fits  J0258-0028
# 1               sdss_a/spec-0410-51877-0623.fits  J0300+0048
# 2               sdss_a/spec-7281-57007-0616.fits  J0802+5513
# 3               sdss_a/spec-1923-53319-0023.fits  J0809+1818
# 4               sdss_a/spec-8280-57061-0366.fits  J0835+4242
# 5               sdss_a/spec-0767-52252-0321.fits  J0920+5240
# 6               sdss_a/spec-5715-56657-0505.fits  J0935+5755
# 7               sdss_a/spec-0503-51999-0464.fits  J1019+0225
# 8               sdss_a/spec-1008-52707-0124.fits  J1023+5005
# 9               sdss_a/spec-5344-55924-0796.fits  J1032+0835
# 10              sdss_a/spec-8851-57460-0737.fits  J1044+3656
# 11             sdss_b/spec-11386-58514-0593.fits  J1055+3124
# 12  spec_cand_snr5new/spec-10269-58220-0671.fits  J1055+3659
# 13              sdss_a/spec-3839-55575-0812.fits  J1125+0029
# 14              sdss_a/spec-4730-55630-0172.fits  J1128+0113
# 15              sdss_a/spec-4765-55674-0082.fits  J1154+0300
# 16              sdss_a/spec-6476-56358-0374.fits  J1214+2803
# 17              sdss_a/spec-1695-53473-0075.fits  J1259+1213
# 18              sdss_a/spec-7428-56781-0528.fits  J1347+4654
# 25  14.875  13.866   0.053   0.066   0.059  AAA  222  0  2.451323e+06
# 26  14.875  13.866   0.053   0.066   0.059  AAA  222  0  2.451323e+06
# 27  14.905  14.787   0.066   0.067   0.098  AAA  222  0  2.451648e+06
# 28  15.252  14.562   0.067   0.076   0.081  AAA  222  0  2.451231e+06
# 29  15.771  15.426   0.134   0.161   0.221  BCD  222  0  2.451307e+06
# 30  15.574  15.509   0.144     NaN     NaN  BUU  200  0  2.451586e+06
# 31  15.111  14.174   0.070   0.071   0.060  AAA  222  0  2.451091e+06
# 32  14.891  14.694   0.059   0.051   0.092  AAA  222  0  2.451085e+06
#
# [33 rows x 24 columns]

# %%
df.query('ra>60 & ra<270 & Jmag<17.2 & Kmag<16.6', inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.columns
# Out:
# Index(['angDist', 'ra', 'dec', 'z', 'userClass', 'relapath', 'Name', 'Coord',
#        '2MASS', 'RAJ2000', 'DEJ2000', 'errHalfMaj', 'errHalfMin', 'errPosAng',
#        'Jmag', 'Hmag', 'Kmag', 'e_Jmag', 'e_Hmag', 'e_Kmag', 'Qfl', 'Rfl', 'X',
#        'MeasureJD'],
#       dtype='object')

# %%
df = df.loc[:,['Name','ra','dec','z','Jmag','Hmag','Kmag','relapath']]

# %%
df.drop_duplicates(subset='ra', inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#           Name         ra        dec         z    Jmag    Hmag    Kmag  \
# 0   J0802+5513  120.70079  55.224685  0.663171  16.467  15.944  14.659
# 1   J0809+1818  122.48913  18.301229  0.966473  16.297  15.798  15.303
# 2   J0835+4242  128.84490  42.716203  0.805863  15.948  15.698  15.048
# 3   J0920+5240  140.14830  52.668445  0.794352  16.562  15.855  15.166
# 4   J0935+5755  143.77683  57.925833  1.531131  16.158  15.285  15.008
# 5   J1019+0225  154.86405   2.422622  1.362947  16.369  15.215  15.114
# 6   J1023+5005  155.84501  50.083578  1.592925  16.991  16.257  15.746
# 7   J1032+0835  158.23072   8.584236  0.893494  15.772  15.655  15.238
# 8   J1044+3656  161.24837  36.934765  0.701929  15.547  15.163  14.335
# 9   J1055+3124  163.87001  31.403133  0.493223  15.923  15.425  14.457
# 10  J1055+3659  163.89057  36.993476  1.577747  17.069  15.761  15.516
# 11  J1125+0029  171.35886   0.483701  0.862571  16.513  16.318  15.362
# 12  J1128+0113  172.11797   1.227217  0.893074  16.570  16.280  15.929
# 13  J1154+0300  178.65251   3.001771  1.458185  16.050  15.416  15.228
# 14  J1214+2803  183.67629  28.058105  0.688845  15.806  15.659  14.601
# 15  J1259+1213  194.92834  12.220167  0.751274  17.004  16.390  15.323
# 16  J1347+4654  206.84513  46.907928  0.697429  16.343  15.735  15.156
# 17  J1353+4651  208.36770  46.851708  1.391569  16.602  15.800  15.811
# 18  J1408+3054  212.02587  30.913462  0.849031  16.097  15.650  14.996
# 19  J1414+1856  213.61793  18.946104  0.607259  17.119  16.065  14.994
# 20  J1419+1219  214.75928  12.330388  1.463434  16.538  15.629  15.377
# 21  J1448+4043  222.00061  40.719921  0.803417  15.127  14.909  14.326
# 22  J1508+6055  227.20332  60.931082  1.532846  16.189  15.241  14.756
# 23  J1523+3914  230.96011  39.234787  0.664138  15.362  14.875  13.866
# 24  J1556+3517  239.14073  35.299264  1.490875  15.912  14.905  14.787
# 25  J1601+1502  240.43234  15.043818  0.647456  15.722  15.252  14.562
# 26  J1605+4743  241.49526  47.716727  0.899965  16.502  15.771  15.426
# 27  J1652+4140  253.15957  41.676525  0.844072  16.573  15.574  15.509
#
#                                         relapath
# 0               sdss_a/spec-7281-57007-0616.fits
# 1               sdss_a/spec-1923-53319-0023.fits
# 2               sdss_a/spec-8280-57061-0366.fits
# 3               sdss_a/spec-0767-52252-0321.fits
# 4               sdss_a/spec-5715-56657-0505.fits
# 5               sdss_a/spec-0503-51999-0464.fits
# 6               sdss_a/spec-1008-52707-0124.fits
# 7               sdss_a/spec-5344-55924-0796.fits
# 8               sdss_a/spec-8851-57460-0737.fits
# 9              sdss_b/spec-11386-58514-0593.fits
# 10  spec_cand_snr5new/spec-10269-58220-0671.fits
# 11              sdss_a/spec-3839-55575-0812.fits
# 12              sdss_a/spec-4730-55630-0172.fits
# 13              sdss_a/spec-4765-55674-0082.fits
# 14              sdss_a/spec-6476-56358-0374.fits
# 15              sdss_a/spec-1695-53473-0075.fits
# 16              sdss_a/spec-7428-56781-0528.fits
# 17              sdss_a/spec-6749-56370-0104.fits
# 18              sdss_a/spec-3862-55276-0124.fits
# 19              sdss_b/spec-2758-54523-0614.fits
# 20   spec_cand_snr5new/spec-5458-56011-0221.fits
# 21              sdss_a/spec-5172-56071-0836.fits
# 22              sdss_a/spec-0611-52055-0114.fits
# 23              sdss_b/spec-4979-56045-0804.fits
# 24              sdss_a/spec-4965-55721-0548.fits
# 25              sdss_b/spec-2524-54568-0356.fits
# 26   spec_cand_snr5new/spec-6320-56453-0162.fits
# 27              sdss_a/spec-0631-52079-0181.fits

# %%
df.to_csv('./tspec23a_2mass_selected.csv', index=False)

# %%
# for i, name in enumerate(dfo['Name']):
#     if ~np.isnan(dfo.Separation[i]):
#         print("\\begin{{Target}}\n\
# \\targname{{{}}}\n\
# \\targra{{{}}}\n\
# \\targdec{{{}}}\n\
# \\targinfo{{J={:.2f}, $z={:.3f}$, FIR}}\n\
# \\end{{Target}}".format(name, 
#                         dfo['srahms2'][i], 
#                         dfo['sdecdms2'][i],dfo['Jmag'][i],dfo['z'][i]))
#     else:
#         print("\\begin{{Target}}\n\
# \\targname{{{}}}\n\
# \\targra{{{}}}\n\
# \\targdec{{{}}}\n\
# \\targinfo{{J={:.2f}, $z={:.3f}$}}\n\
# \\end{{Target}}".format(name, 
#                         dfo['srahms2'][i], 
#                         dfo['sdecdms2'][i],dfo['Jmag'][i],dfo['z'][i]))
